# %%
# Step 1: Import necessary libraries
import pandas as pd
import folium

# %%
# Step 2: Load the CSV file into a pandas DataFrame
file_path = 'Contaminated_Lands_in_Colorado_20241015_v2.csv'  # Adjust path based on your environment
df = pd.read_csv(file_path)

# Check the first few rows to ensure the data is loaded correctly
df.head(10)
# Out:
#                         the_geom   gid              program  \
# 0  POINT (-107.766266 37.960952)  1345           Brownfield
# 1  POINT (-107.730183 37.932621)  1324           Brownfield
# 2  POINT (-107.728001 37.942002)  1303           Brownfield
# 3  POINT (-107.780147 37.969739)  1374           Brownfield
# 4    POINT (-104.98027 39.79333)   101  Abandoned Mine Land
# 5  POINT (-105.119179 39.717373)  6365                 RCRA
# 6          POINT (-107.77 37.99)  1327           Brownfield
# 7  POINT (-107.698784 37.985308)  1270           Brownfield
# 8        POINT (-105.466 37.347)    96  Abandoned Mine Land
# 9  POINT (-107.778432 37.969418)  1292           Brownfield
#
#                     site_name                         city state  mapped_acr  \
# 0                      Lizard  Unincorporated Ouray County    CO       10.85
# 1                    Honolulu  Unincorporated Ouray County    CO       10.34
# 2                    Gertrude  Unincorporated Ouray County    CO       10.26
# 3                       Nuada  Unincorporated Ouray County    CO        7.85
# 4  ASARCO, INC. (GLOBE PLANT)                       DENVER    CO     1010.00
# 5      General Services Admin                     Lakewood    CO      690.00
# 6                     Ilda G.  Unincorporated Ouray County    CO       10.34
# 7               Croesus No. 5  Unincorporated Ouray County    CO        9.64
# 8             CEDAR RESOURCES                      CONEJOS    CO        0.00
# 9                       Fargo  Unincorporated Ouray County    CO       10.34
#
#     Latitude   Longitude
# 0  37.960952 -107.766266
# 1  37.932621 -107.730183
# 2  37.942002 -107.728001
# 3  37.969739 -107.780147
# 4  39.793330 -104.980270
# 5  39.717373 -105.119179
# 6  37.990000 -107.770000
# 7  37.985308 -107.698784
# 8  37.347000 -105.466000
# 9  37.969418 -107.778432

# %%
# Step 3: Select relevant columns
columns = ['the_geom', 'gid', 'program', 'site_name', 'city', 'state', 'mapped_acr', 'Latitude', 'Longitude']
df_filtered = df[columns]

# Check for missing or NaN values in latitude and longitude
df_filtered = df_filtered.dropna(subset=['Latitude', 'Longitude'])

# Ensure the correct data types for latitude and longitude
df_filtered['Latitude'] = pd.to_numeric(df_filtered['Latitude'], errors='coerce')
df_filtered['Longitude'] = pd.to_numeric(df_filtered['Longitude'], errors='coerce')

# %%
# Step 4: Create a map centered on Colorado (or adjust based on your data)
colorado_map = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Step 5: Add markers to the map
for idx, row in df_filtered.iterrows():
    # Extract relevant data for each marker
    site_name = row['site_name']
    program = row['program']
    city = row['city']
    mapped_acres = row['mapped_acr']
    latitude = row['Latitude']
    longitude = row['Longitude']
    
    # Create popup content
    popup_content = (
        f"""
        <b>Site Name:</b> {site_name}<br>
        <b>Program:</b> {program}<br>
        <b>City:</b> {city}<br>
        <b>Mapped Acres:</b> {mapped_acres}<br>
        """
    )
    
    # Add marker to the map
    folium.Marker(
        location=[latitude, longitude],
        popup=folium.Popup(popup_content, max_width=250),
        icon=folium.Icon(color='orange', icon='radiation', prefix='fa')
    ).add_to(colorado_map)

# Step 6: Display the map
colorado_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_30d8c03862daff3e365b746ec4c744cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_30d8c03862daff3e365b746ec4c744cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_30d8c03862daff3e365b746ec4c744cf = L.map(
#                 &quot;map_30d8c03862daff3e365b746ec4c744cf&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d4e94185740ac37d1f76b7681700f87 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8d4e94185740ac37d1f76b7681700f87.addTo(map_30d8c03862daff3e365b746ec4c744cf);
#
#
#             var marker_b22e69db082bd5960db2c65337562532 = L.marker(
#                 [37.960952, -107.766266],
#                 {}
#             ).addTo(map_30d8c03862daff3e365b746ec4c744cf);
#
#
#             var icon_399237ece02f0978b7ee178add0e6d20 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;radiation&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b22e69db082bd5960db2c65337562532.setIcon(icon_399237ece02f0978b7ee178add0e6d20);
#
#
#         var popup_597e583b4742b27fead8503263146307 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_04583a42b68ed0aeb4032a47c19afaee = $(`&lt;div id=&quot;html_04583a42b68ed0aeb4032a47c19afaee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Site Name:&lt;/b&gt; Lizard&lt;br&gt;         &lt;b&gt;Program:&lt;/b&gt; Brownfield&lt;br&gt;         &lt;b&gt;City:&lt;/b&gt; Unincorporated Ouray County&lt;br&gt;         &lt;b&gt;Mapped Acres:&lt;/b&gt; 10.85&lt;br&gt;         &lt;/div&gt;`)[0];
#                 popup_597e583b4742b27fead8503263146307.setContent(html_04583a42b68ed0aeb4032a47c19afaee);
#
#
#
#         marker_b22e69db082bd5960db2c65337562532.bindPopup(popup_597e583b4742b27fead8503263146307)
#         ;
#
#
#
#
#             var marker_8611d35e9e65ff404c5abaa2f15f7f38 = L.marker(
#                 [37.932621, -107.730183],
#                 {}
#             ).addTo(map_30d8c03862daff3e365b746ec4c744cf);
#
#
#             var icon_7afa2aa666e76a02efa146e10818cb31 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;radiation&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8611d35e9e65ff404c5abaa2f15f7f38.setIcon(icon_7afa2aa666e76a02efa146e10818cb31);
#
#
#         var popup_bd1aa5b09f687ca627d53c419d5005e8 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_8b5888d0147d2cf30a488c9f7924fa7a = $(`&lt;div id=&quot;html_8b5888d0147d2cf30a488c9f7924fa7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Site Name:&lt;/b&gt; Honolulu&lt;br&gt;         &lt;b&gt;Program:&lt;/b&gt; Brownfield&lt;br&gt;         &lt;b&gt;City:&lt;/b&gt; Unincorporated Ouray County&lt;br&gt;         &lt;b&gt;Mapped Acres:&lt;/b&gt; 10.34&lt;br&gt;         &lt;/div&gt;`)[0];
#                 popup_bd1aa5b09f687ca627d53c419d5005e8.setContent(html_8b5888d0147d2cf30a488c9f7924fa7a);
#
#
#
#         marker_8611d35e9e65ff404c5abaa2f15f7f38.bindPopup(popup_bd1aa5b09f687ca627d53c419d5005e8)
#         ;
#
#
#
#
#             var marker_cb14126fd06a15ed2cd488e683d226c1 = L.marker(
#                 [37.942002, -107.728001],
#                 {}
#             ).addTo(map_30d8c03862daff3e365b746ec4c744cf);
#
#
#             var icon_47e79d00307ff95b7ee2f8f597b04937 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;radiation&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_cb14126fd06a15ed2cd488e683d226c1.setIcon(icon_47e79d00307ff95b7ee2f8f597b04937);
#
#
#         var popup_59cc5d6119f871b310f9e502b1d30686 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_624e4a2a6674b084e1f518927926e02d = $(`&lt;div id=&quot;html_624e4a2a6674b084e1f518927926e02d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Site Name:&lt;/b&gt; Gertrude&lt;br&gt;         &lt;b&gt;Program:&lt;/b&gt; Brownfield&lt;br&gt;         &lt;b&gt;City:&lt;/b&gt; Unincorporated Ouray County&lt;br&gt;         &lt;b&gt;Mapped Acres:&lt;/b&gt; 10.26&lt;br&gt;         &lt;/div&gt;`)[0];
#                 popup_59cc5d61

# %%
# Save the map to an HTML file
colorado_map.save("contaminated_lands_in_colorado_map.html")
